# %% [markdown]
# # Analyze Data Anomalies

# %%
from valuation.infra.file.io import IOService

# %% [markdown]
# ## Negative Gross Profit

# %%
filepath = "logs/dataset.2025-10-21_12-05-39/validation_failed_records/Aggregated_gross_profit_contains_208_negative_values.csv"
IOService.read(filepath=filepath)
# Out:
#      store          upc  week  move  qty  price  gross_margin_pct  ok  \
# 0        9  30573020045   240     4    1   5.89             -0.67   1
# 1       14  31981000893   244     2    1   5.99            -19.69   1
# 2      130  31981000166   243     2    1   6.99             -2.57   1
# 3        8   7336011301   250    17    1  10.75            -13.39   1
# 4        9   3410057306   227    16    1   9.99             -9.40   1
# ..     ...          ...   ...   ...  ...    ...               ...  ..
# 203    139  30041085115   280     2    1   1.99             -3.01   1
# 204      8   5400046510   283   202    1   0.47             -4.28   1
# 205     77   4200013000   220    24    1   1.14             -1.49   1
# 206    106   3700060571   226   517    1   0.79            -25.31   1
# 207    132   5400041500   229  1190    1   0.50             -3.80   1
#
#             price_hex        profit_hex          category       start  \
# ...
