# %%
from valuation.utils.io import IOKwargs


dc = IOKwargs()
print(dc)
# Out:
#                        IOKwargs.csv.read
# ...
#                              sep | ,
#                           header | infer
#                        index_col | None
#                          usecols | None
#                 mangle_dupe_cols | True
#                            dtype | None
#                           engine | c
#                        na_values | None
#                  keep_default_na | True
#                        na_filter | True
#                          verbose | False
#                 skip_blank_lines | True
#                      parse_dates | False
#            infer_datetime_format | False
#                    keep_date_col | False
#                        day_first | False
#                      cache_dates | True
#                      compression | infer
#                        thousands | None
#                   lineterminator |
#
#                       low_memory | False
#                         encoding | utf-8
# ...
